# %%
import xmlread
from tqdm import tqdm
import pickle

# %%
all_nodules = []
for file in tqdm(xmlread.files):
    nodules = xmlread.leer(file)
    all_nodules.extend(nodules)
# Out:
#   2%|▏         | 27/1318 [00:00<00:05, 250.03it/s]
# data/lidc-xml/186/212.xml
# data/lidc-xml/186/254.xml
# NoduleID 174001
# NoduleID 174012
# NoduleID 0
# NoduleID 6
# NoduleID 172251
# NoduleID 172261
# NoduleID Nodule 001
# NoduleID Nodule 002
# data/lidc-xml/186/072.xml
# data/lidc-xml/186/105.xml
# data/lidc-xml/186/034.xml
# NoduleID Nodule 001
# NoduleID 98644
# NoduleID 98657
# NoduleID 98665
# NoduleID 106231
# NoduleID 7
# data/lidc-xml/186/127.xml
# NoduleID 0
# NoduleID 6
# NoduleID 8
# NoduleID 115424
# NoduleID 115418
# NoduleID 115426
# NoduleID 115429
# NoduleID 135160
# NoduleID 135164
# NoduleID 135154
# NoduleID 135724
# NoduleID Nodule 001
# NoduleID Nodule 002
# data/lidc-xml/186/191.xml
# NoduleID Nodule 001
# NoduleID 10104
# NoduleID 6003
# NoduleID IL057_123483
# data/lidc-xml/186/150.xml
# data/lidc-xml/186/220.xml
# NoduleID 0
# NoduleID 1
# NoduleID 2
# NoduleID 163289
# NoduleID 161380
# NoduleID 161382
# NoduleID Nodule 001
# data/lidc-xml/186/088.xml
# ...

# %%
pickle.dump(all_nodules, open("data/nodule_segmentation_polygons.pkl", "wb"))
